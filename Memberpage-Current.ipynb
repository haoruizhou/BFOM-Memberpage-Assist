# %%
import pandas as pd
memberList = pd.read_csv('memberListCurrent.csv', sep=';')
memberList = memberList.fillna('')
print(memberList)
# Out:
#                   name              nameAndPronouns               fileName  \
# 0          Max Jimenez         Max Jimenez (he/him)         MaxJimenez.jpg
# 1           Hally Zhou         Hally Zhou (he/they)          HallyZhou.jpg
# 2       Kausik Kolluri      Kausik Kolluri (he/him)     KausikKolluri.jpeg
# 3             Will Heo            Will Heo (he/him)            WillHeo.jpg
# 4        Dylan Gardner       Dylan Gardner (he/him)       DylanGardner.jpg
# 5           Danny Rose          Danny Rose (he/him)          DannyRose.jpg
# 6   Daniel Simanjuntak  Daniel Simanjuntak (he/him)  DanielSimanjuntak.jpg
# 7            Will Peng           Will Peng (he/him)           WillPeng.jpg
# 8           Daric Zhou          Daric Zhou (he/him)          DaricZhou.jpg
# 9         Seth Purohit        Seth Purohit (he/him)        SethPurohit.jpg
# 10         Daniel Roth         Daniel Roth (he/him)         DanielRoth.jpg
# 11     Miguel Ocegueda  Miguel Ocegueda (he/him/el)     MiguelOcegueda.jpg
# 12          Jimmy Mack          Jimmy Mack (he/him)          JimmyMack.jpg
# 13         Aaron Zolla         Aaron Zolla (he/him)         AaronZolla.jpg
# 14        Andrew White        Andrew White (he/him)        AndrewWhite.jpg
# 15       Robson Little       Robson Little (he/him)       RobsonLittle.jpg
# 16     Nicolas Ferrari     Nicolas Ferrari (he/him)     NicolasFerrari.jpg
#
#                                        accessibleText             parts  \
# 0                 photo of Max Jimenez with a. guitar          Baritone
# 1   photo of Hally Zhou sitting on the wing struct...              Bass
# 2                  photo of Kausik Kolluri in Chicago          Tenor II
# 3       photo of Will Heo smiling with a black jacket             Tenor
# 4         photo of Dylan Gardner near a shallow river          Baritone
# 5                   photo of Danny Rose during a hike             Tenor
# 6                         photo of Daniel Simanjuntak  Vocal Percussion
# 7                                  photo of Will Peng              Bass
# 8                   photo of Daric Zhou in Santa Cruz          Baritone
# 9                               photo of Seth Purohit          Tenor II
# 10                               photo of Daniel Roth           Tenor I
# 11                           photo of Miguel Ocegueda          Baritone
# 12                                photo of Jimmy Mack           Tenor I
# 13                               photo of Aaron Zolla          Baritone
# 14                              photo of Andrew White              Bass
# 15                             photo of Robson Little              Bass
# 16                           photo of Nicolas Ferrari          Baritone
#
#                                                 quote        position  \
# 0                                               Quote       President
# 1                        Singing on frequency in air.  Vice President
# 2       The best part of bfom is the people you meet.       Treasurer
# 3                                               Quote  Music Director
# 4                                               Quote    Social Chair
# 5                               Shirt bras and slaps.
# 6                                               Quote
# 7                                               Quote
# 8                                               quote
# 9   Be more concerned with your character than you...
# 10    Every experience is an opportunity for a story.
# 11  Darkness cannot drive out darkness, only light...
# 12  Sometimes you just have to blow things up, and...
# 13                                              Quote
# 14  Oh, you're still here... - my sister the day I...
# 15                                      No worries :)
# 16                         Honesty's the best policy.
#
#                                       xYearMajorMinor
# 0                         4th Year, Political Science
# 1   3rd Year, Geography and Psychological & Brain ...
# 2                                   2nd Year, Physics
# 3                           2nd Year Ph.D., Economics
# 4                         2nd Year, Political Science
# 5                          2nd Year, Computer Science
# 6                    4th Year, Economics & Accounting
# 7                              2nd Year, Data Science
# 8                       3rd Year, Applied Mathematics
# 9                                   1st Year, Pre-Bio
# 10                             2nd Year, Biochemistry
# 11                                  2nd Year, Pre-Bio
# 12                     1st Year, Computer Engineering
# 13                    1st Year, Pre-Political Science
# 14   1st Year PhD, Biochemistry and Molecular Biology
# 15                               2nd Year, Undeclared
# 16         3rd Year, Psychological and Brain Sciences

# %%
# define
name = ""
# this is the text shown if image doesn't load
# example: Hally Zhou
# case NOT sensitive
fileName = ""
# this is the file name of the member's photo
# example: HallyZhou.jpg
# case SENSITIVE, practice
accessibleText = ""
# this text is for people who have impaired vision, when they use screen reader, this is the text they will hear
# example: Vice President Hally Zhou
# case NOT sensitive
parts = ""
# example: Bass
# case NOT sensitive
quote = ""
# example: "some quote"
# case NOT sensitive
position = ""
# example = "Vice President"
# case NOT sensitive
nameAndPronouns = ""
# this is your name and pronouns
# example: Hally Zhou (he/they)
# case NOT sensitive
xYearMajorMinor = ""
# example: 3rd Year Geography and Psychological & Brain Sciences
# case SENSITIVE
oneMember = ""
fourMember = ""
nameHeader = ""
# a string of 4 or less names that shows who's included in this code block

output = ""

# %%
def oneMember(name, fileName, accessibleText, parts, quote, nameAndPronouns, position, xYearMajorMinor):

    temp = """
                <!-- NEW MEMBER HERE -->

                <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
                    <div class="team-member">
                        <div class="team-img">
                            <img src="img/members/{fileName}" id = "{name}" alt="{accessibleText}" class="img-responsive">
                        </div>
                        <div class="team-hover">
                            <div class="desk">
                                <h4>{parts}</h4>
                                <p>{quote}</p>
                            </div>
                        </div>
                    </div>
                    <div class="team-title">
                        <h4>{nameAndPronouns}</h4>
                        <h5>{position}</h5>
                        <span>{xYearMajorMinor}</span>
                    </div>
                </div>

""".format(fileName = fileName, name = name, accessibleText = accessibleText, parts = parts, quote = quote, nameAndPronouns= nameAndPronouns, position = position, xYearMajorMinor = xYearMajorMinor)
    return temp

def templateOutsideBracket(nameHeader, fourMember):
    temp = """
                <!-- USE THIS TEMPLATE FOR EACH NEW ROW. REPLACE NAME/MAJOR/PARTS/POSITION/QUOTE PLACEHOLDER -->

                <!-- NEW ROW EVERY 4 MEMBERS -->
                <!-- LIST NAMES HERE FOR QUICK REFERENCE -->
                <!-- {nameHeader} -->
                <div class = "row" style = "margin-top:50px;">
                    {memberInfo}
                </div>
                <!-- END OF A FOUR PEOPLE BLOCK -->

    """.format(nameHeader = nameHeader, memberInfo = fourMember)

    return temp

# %%
counter = 0

for i in range (len(memberList.index)):
    counter += 1
    print(memberList['name'].values[i])
    name = memberList['name'].values[i]
    nameHeader = str(nameHeader) + " " + str(name)
    nameAndPronouns = memberList['nameAndPronouns'].values[i]
    fileName = memberList['fileName'].values[i]
    accessibleText = memberList['accessibleText'].values[i]
    parts = memberList['parts'].values[i]
    quote = memberList['quote'].values[i]
    position = memberList['position'].values[i]
    xYearMajorMinor = memberList['xYearMajorMinor'].values[i]

    temp = oneMember(name, fileName, accessibleText, parts, quote, nameAndPronouns, position, xYearMajorMinor)
    fourMember = fourMember + temp

    if counter == 4 or i == len(memberList.index)-1:
        # 4 members is one row
        temp = templateOutsideBracket(nameHeader, fourMember)
        output = output + temp
        counter = 0
        fourMember = ""
        nameHeader = ""

    print(i)
# Out:
# Max Jimenez
# 0
# Hally Zhou
# 1
# Kausik Kolluri
# 2
# Will Heo
# 3
# Dylan Gardner
# 4
# Danny Rose
# 5
# Daniel Simanjuntak
# 6
# Will Peng
# 7
# Daric Zhou
# 8
# Seth Purohit
# 9
# Daniel Roth
# 10
# Miguel Ocegueda
# 11
# Jimmy Mack
# 12
# Aaron Zolla
# 13
# Andrew White
# 14
# Robson Little
# 15
# Nicolas Ferrari
# 16

# %%
print(output)

with open('outputCurrent.txt', 'w') as f:
    f.write(output)
# Out:
#                 <!-- USE THIS TEMPLATE FOR EACH NEW ROW. REPLACE NAME/MAJOR/PARTS/POSITION/QUOTE PLACEHOLDER -->
#
#                 <!-- NEW ROW EVERY 4 MEMBERS -->
#                 <!-- LIST NAMES HERE FOR QUICK REFERENCE -->
#                 <!--  Max Jimenez Hally Zhou Kausik Kolluri Will Heo -->
#                 <div class = "row" style = "margin-top:50px;">
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/MaxJimenez.jpg" id = "Max Jimenez" alt="photo of Max Jimenez with a. guitar" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Baritone</h4>
#                                 <p>Quote</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Max Jimenez (he/him)</h4>
#                         <h5>President</h5>
#                         <span>4th Year, Political Science</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/HallyZhou.jpg" id = "Hally Zhou" alt="photo of Hally Zhou sitting on the wing struct of a Cessna airplane" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Bass</h4>
#                                 <p>Singing on frequency in air.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Hally Zhou (he/they)</h4>
#                         <h5>Vice President</h5>
#                         <span>3rd Year, Geography and Psychological & Brain Sciences</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/KausikKolluri.jpeg" id = "Kausik Kolluri" alt="photo of Kausik Kolluri in Chicago" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Tenor II</h4>
#                                 <p>The best part of bfom is the people you meet.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Kausik Kolluri (he/him)</h4>
#                         <h5>Treasurer</h5>
#                         <span>2nd Year, Physics</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/WillHeo.jpg" id = "Will Heo" alt="photo of Will Heo smiling with a black jacket" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Tenor</h4>
#                                 <p>Quote</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Will Heo (he/him)</h4>
#                         <h5>Music Director</h5>
#                         <span>2nd Year Ph.D., Economics</span>
#                     </div>
#                 </div>
#
#
#                 </div>
#                 <!-- END OF A FOUR PEOPLE BLOCK -->
#
#
#                 <!-- USE THIS TEMPLATE FOR EACH NEW ROW. REPLACE NAME/MAJOR/PARTS/POSITION/QUOTE PLACEHOLDER -->
#
#                 <!-- NEW ROW EVERY 4 MEMBERS -->
#                 <!-- LIST NAMES HERE FOR QUICK REFERENCE -->
#                 <!--  Dylan Gardner Danny Rose Daniel Simanjuntak Will Peng -->
#                 <div class = "row" style = "margin-top:50px;">
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/DylanGardner.jpg" id = "Dylan Gardner" alt="photo of Dylan Gardner near a shallow river" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Baritone</h4>
#                                 <p>Quote</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Dylan Gardner (he/him)</h4>
#                         <h5>Social Chair</h5>
#                         <span>2nd Year, Political Science</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/DannyRose.jpg" id = "Danny Rose" alt="photo of Danny Rose during a hike" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Tenor</h4>
#                                 <p>Shirt bras and slaps.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Danny Rose (he/him)</h4>
#                         <h5></h5>
#                         <span>2nd Year, Computer Science</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/DanielSimanjuntak.jpg" id = "Daniel Simanjuntak" alt="photo of Daniel Simanjuntak" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Vocal Percussion</h4>
#                                 <p>Quote</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Daniel Simanjuntak (he/him)</h4>
#                         <h5></h5>
#                         <span>4th Year, Economics & Accounting</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/WillPeng.jpg" id = "Will Peng" alt="photo of Will Peng" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Bass</h4>
#                                 <p>Quote</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Will Peng (he/him)</h4>
#                         <h5></h5>
#                         <span>2nd Year, Data Science</span>
#                     </div>
#                 </div>
#
#
#                 </div>
#                 <!-- END OF A FOUR PEOPLE BLOCK -->
#
#
#                 <!-- USE THIS TEMPLATE FOR EACH NEW ROW. REPLACE NAME/MAJOR/PARTS/POSITION/QUOTE PLACEHOLDER -->
#
#                 <!-- NEW ROW EVERY 4 MEMBERS -->
#                 <!-- LIST NAMES HERE FOR QUICK REFERENCE -->
#                 <!--  Daric Zhou Seth Purohit Daniel Roth Miguel Ocegueda -->
#                 <div class = "row" style = "margin-top:50px;">
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/DaricZhou.jpg" id = "Daric Zhou" alt="photo of Daric Zhou in Santa Cruz" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Baritone</h4>
#                                 <p>quote</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Daric Zhou (he/him)</h4>
#                         <h5></h5>
#                         <span>3rd Year, Applied Mathematics</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/SethPurohit.jpg" id = "Seth Purohit" alt="photo of Seth Purohit" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Tenor II</h4>
#                                 <p>Be more concerned with your character than your reputation, because your character is what you really are, while your reputation is merely what others think you are.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Seth Purohit (he/him)</h4>
#                         <h5></h5>
#                         <span>1st Year, Pre-Bio</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/DanielRoth.jpg" id = "Daniel Roth" alt="photo of Daniel Roth" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Tenor I</h4>
#                                 <p>Every experience is an opportunity for a story.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Daniel Roth (he/him)</h4>
#                         <h5></h5>
#                         <span>2nd Year, Biochemistry</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/MiguelOcegueda.jpg" id = "Miguel Ocegueda" alt="photo of Miguel Ocegueda" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Baritone</h4>
#                                 <p>Darkness cannot drive out darkness, only light can do that. Hate cannot drive out hate, only love can do that.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Miguel Ocegueda (he/him/el)</h4>
#                         <h5></h5>
#                         <span>2nd Year, Pre-Bio</span>
#                     </div>
#                 </div>
#
#
#                 </div>
#                 <!-- END OF A FOUR PEOPLE BLOCK -->
#
#
#                 <!-- USE THIS TEMPLATE FOR EACH NEW ROW. REPLACE NAME/MAJOR/PARTS/POSITION/QUOTE PLACEHOLDER -->
#
#                 <!-- NEW ROW EVERY 4 MEMBERS -->
#                 <!-- LIST NAMES HERE FOR QUICK REFERENCE -->
#                 <!--  Jimmy Mack Aaron Zolla Andrew White Robson Little -->
#                 <div class = "row" style = "margin-top:50px;">
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/JimmyMack.jpg" id = "Jimmy Mack" alt="photo of Jimmy Mack" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Tenor I</h4>
#                                 <p>Sometimes you just have to blow things up, and that's okay.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Jimmy Mack (he/him)</h4>
#                         <h5></h5>
#                         <span>1st Year, Computer Engineering</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/AaronZolla.jpg" id = "Aaron Zolla" alt="photo of Aaron Zolla" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Baritone</h4>
#                                 <p>Quote</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Aaron Zolla (he/him)</h4>
#                         <h5></h5>
#                         <span>1st Year, Pre-Political Science</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/AndrewWhite.jpg" id = "Andrew White" alt="photo of Andrew White" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Bass</h4>
#                                 <p>Oh, you're still here... - my sister the day I moved out.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Andrew White (he/him)</h4>
#                         <h5></h5>
#                         <span>1st Year PhD, Biochemistry and Molecular Biology</span>
#                     </div>
#                 </div>
#
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/RobsonLittle.jpg" id = "Robson Little" alt="photo of Robson Little" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Bass</h4>
#                                 <p>No worries :)</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Robson Little (he/him)</h4>
#                         <h5></h5>
#                         <span>2nd Year, Undeclared</span>
#                     </div>
#                 </div>
#
#
#                 </div>
#                 <!-- END OF A FOUR PEOPLE BLOCK -->
#
#
#                 <!-- USE THIS TEMPLATE FOR EACH NEW ROW. REPLACE NAME/MAJOR/PARTS/POSITION/QUOTE PLACEHOLDER -->
#
#                 <!-- NEW ROW EVERY 4 MEMBERS -->
#                 <!-- LIST NAMES HERE FOR QUICK REFERENCE -->
#                 <!--  Nicolas Ferrari -->
#                 <div class = "row" style = "margin-top:50px;">
#
#                 <!-- NEW MEMBER HERE -->
#
#                 <div class="col-md-3 col-sm-3" style="margin-bottom:15px">
#                     <div class="team-member">
#                         <div class="team-img">
#                             <img src="img/members/NicolasFerrari.jpg" id = "Nicolas Ferrari" alt="photo of Nicolas Ferrari" class="img-responsive">
#                         </div>
#                         <div class="team-hover">
#                             <div class="desk">
#                                 <h4>Baritone</h4>
#                                 <p>Honesty's the best policy.</p>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="team-title">
#                         <h4>Nicolas Ferrari (he/him)</h4>
#                         <h5></h5>
#                         <span>3rd Year, Psychological and Brain Sciences</span>
#                     </div>
#                 </div>
#
#
#                 </div>
#                 <!-- END OF A FOUR PEOPLE BLOCK -->
